# %% [markdown]
# <a href="https://colab.research.google.com/github/UjanGanguli/Python-Basics/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib

# %% [markdown]
# 1. Number of covid-19 cases in a day

# %%
import numpy as np
import seaborn as sns
sns.set(style="white")
rs=np.random.RandomState(10)
d=rs.normal(size=50)
sns.displot(d,kde=True,color='g')

# %% [markdown]
# 2. The data of the patients in a hospital

# %%
import pandas as pd
data={'Name':['VIJAY','AJITH','JAI','SURIYA'],'AGE':[48,52,30,44]}
df=pd.DataFrame(data)
df
# Out:
#      Name  AGE
# 0   VIJAY   48
# 1   AJITH   52
# 2     JAI   30
# 3  SURIYA   44

# %% [markdown]
# 3. Storing the data of the patients in a hospital

# %%
import csv
file=open('sample_csv.csv')
type(file)
csvreader=csv.reader(file)
for row in csvreader:
    print(row)
# Out:
# ['Name: AJITH', ' SURIYA', ' VIJAY']
# ['AGE: 52', '44', '50']

# %% [markdown]
# 4. Plotting the name and age of the patients in a scatterplot

# %%
import seaborn
import pandas
data=pandas.read_csv('sample_csv.csv')
seaborn.scatterplot(data['Name'],data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %% [markdown]
# 5. Plotting the age of patients who require the 2nd dose of vaccine

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.boxplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# 6. Plotting the age of patients those who have covid-19

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.boxplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %% [markdown]
# 7. Plotting the age of people those who are in crictical threat from covid-19

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.violinplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
8.

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.violinplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.scatterplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.swarmplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.barplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.barplot(data['Age'],data['Name'],data=data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.pointplot(data['Age'],data['Name'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Name'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.pointplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.countplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.kdeplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
import seaborn as sns
import pandas
data=pandas.read_csv('sample_csv.csv')
sns.distplot(data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>
