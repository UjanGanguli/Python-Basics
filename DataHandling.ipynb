# %% [markdown]
# <a href="https://colab.research.google.com/github/UjanGanguli/Python-Basics/blob/main/DataHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("salary.csv") #No. of rows and columns(607 rows × 10 columns)
df
# Out:
#      Unnamed: 0  Working_Year                 Designation Experience  \
# 0             1          2020              Data Scientist         MI
# 1             2          2020  Machine Learning Scientist         SE
# 2             3          2020           Big Data Engineer         SE
# 3             4          2020        Product Data Analyst         MI
# 4             5          2020   Machine Learning Engineer         SE
# ..          ...           ...                         ...        ...
# 602         603          2022               Data Engineer         SE
# 603         604          2022               Data Engineer         SE
# 604         605          2022                Data Analyst         SE
# 605         606          2022                Data Analyst         SE
# 606         607          2022                AI Scientist         MI
#
#     Employment_Status Salary_In_Rupees Employee_Location Company_Location  \
# ...

# %%
df.isnull().value_counts() #no null values
# Out:
# Unnamed: 0  Working_Year  Designation  Experience  Employment_Status  Salary_In_Rupees  Employee_Location  Company_Location  Company_Size  Remote_Working_Ratio
# False       False         False        False       False              False             False              False             False         False                   607
# dtype: int64

# %%
df.head(20)
# Out:
#     Unnamed: 0  Working_Year                 Designation Experience  \
# 0            1          2020              Data Scientist         MI
# 1            2          2020  Machine Learning Scientist         SE
# 2            3          2020           Big Data Engineer         SE
# 3            4          2020        Product Data Analyst         MI
# 4            5          2020   Machine Learning Engineer         SE
# 5            6          2020                Data Analyst         EN
# 6            7          2020         Lead Data Scientist         SE
# 7            8          2020              Data Scientist         MI
# 8            9          2020       Business Data Analyst         MI
# 9           10          2020          Lead Data Engineer         SE
# 10          11          2020              Data Scientist         EN
# 11          12          2020              Data Scientist         MI
# 12          13          2020              Data Scientist         EN
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Working_Year                 Designation Experience  \
# 0             1          2020              Data Scientist         MI
# 1             2          2020  Machine Learning Scientist         SE
# 2             3          2020           Big Data Engineer         SE
# 3             4          2020        Product Data Analyst         MI
# 4             5          2020   Machine Learning Engineer         SE
# ..          ...           ...                         ...        ...
# 602         603          2022               Data Engineer         SE
# 603         604          2022               Data Engineer         SE
# 604         605          2022                Data Analyst         SE
# 605         606          2022                Data Analyst         SE
# 606         607          2022                AI Scientist         MI
#
#     Employment_Status Salary_In_Rupees Employee_Location Company_Location  \
# ...

# %%
from matplotlib import pyplot as plt

x=df["Designation"]
y=df["Salary_In_Rupees"]
plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')
